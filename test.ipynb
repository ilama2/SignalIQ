# %%
from app.clients.sahmk_client import SahmkClient

client = SahmkClient()

data = client.get_quote("2222")

print(data)
# Out:
# {'symbol': '2222', 'name': 'أرامكو السعودية', 'name_en': 'Saudi Arabian Oil Co', 'price': 26.68, 'change': 0.04, 'change_percent': 0.15, 'open': 26.66, 'high': 26.72, 'low': 26.52, 'previous_close': 26.64, 'volume': 5021419, 'value': 133868103.26, 'bid': 26.68, 'ask': 26.7, 'bid_size': 10218, 'ask_size': 88045, 'liquidity': {'inflow_value': 82905515.84, 'inflow_volume': 3108457, 'inflow_trades': 4060, 'outflow_value': 50962588.12, 'outflow_volume': 1912962, 'outflow_trades': 3622, 'net_value': 31942927.720000006}, 'updated_at': '2026-07-16T12:20:00+00:00', 'is_delayed': True}

# %%
from app.core import settings

print("SAHMK KEY:", settings.SAHMK_API_KEY)
# Out:
# SAHMK KEY: shmk_live_c2d41cfe7ecaca461c4d028f9ca9e4a788f0258d98a362d7

# %%
from app.clients.sahmk_client import SahmkClient

client = SahmkClient()

print(client.headers)
# Out:
# {'Authorization': 'shmk_live_c2d41cfe7ecaca461c4d028f9ca9e4a788f0258d98a362d7', 'Accept': 'application/json'}
